# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from scipy import stats

from sklearn.preprocessing import StandardScaler, MinMaxScaler
dataset = pd.read_csv('Downloads/Titanic_train.csv')
dataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
fare_values = dataset.loc[dataset['Fare'].notnull(), 'Fare'].values
fare_values.shape
# Out:
# (891,)

# %%
plt.hist(fare_values, bins=20)
plt.show()

# %% [markdown]
# ### Średnia

# %%
mean_fare = np.round(np.mean(fare_values))
mean_fare
# Out:
# 32.0

# %%
plt.figure(figsize=(15,10))
plt.hist(fare_values, bins=20)
plt.axvline(x = mean_fare, color='red', label = 'Średnia', linestyle = '--')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# ### Mediana

# %%
median_fare = np.median(fare_values)
median_fare
# Out:
# 14.4542

# %%
plt.figure(figsize=(15,10))
plt.hist(fare_values, bins=20)
plt.axvline(x = mean_fare, color='red', label = 'Średnia', linestyle = '--')
plt.axvline(x = median_fare, color='purple', label = 'Mediana', linestyle = '--')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# ### Moda

# %%
mode_fare = stats.mode(fare_values)
mode_fare
# Out:
# ModeResult(mode=8.05, count=43)

# %%
plt.figure(figsize=(15,10))
plt.hist(fare_values, bins=20)
plt.axvline(x = mean_fare, color='red', label = 'Średnia', linestyle = '--')
plt.axvline(x = median_fare, color='purple', label = 'Mediana', linestyle = '--')
plt.axvline(x = mode_fare[0], color='orange', label = 'Moda', linestyle = '--')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# ### Kwartyle i asymetria

# %%
q0 = np.quantile(fare_values, 0.0)
q1 = np.round(np.quantile(fare_values, 0.25))
q3 = np.round(np.quantile(fare_values, 0.75))
q4 = np.round(np.quantile(fare_values, 1.0))
print(f'Q0: {q0}')
print(f'Q1: {q1}')
print(f'Q2: {median_fare}')
print(f'Q3: {q3}')
print(f'Q4: {q4}')
# Out:
# Q0: 0.0
# Q1: 8.0
# Q2: 14.4542
# Q3: 31.0
# Q4: 512.0

# %%
plt.figure(figsize=(15,10))
plt.hist(fare_values, bins=20)
plt.axvline(x = mean_fare, color='red', label = 'Średnia', linestyle = '--')
plt.axvline(x = median_fare, color='purple', label = 'Mediana', linestyle = '--')
plt.axvline(x = mode_fare[0], color='orange', label = 'Moda', linestyle = '--')
plt.axvline(x = q0, color='black', label = 'Min')
plt.axvline(x = q1, color='black', label = 'Q1')
plt.axvline(x = q3, color='black', label = 'Q3')
plt.axvline(x = q4, color='black', label = 'Max')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# Można łatwo stwierdzić, że mamy doczynienia z asymerią lewstroną dodatnią.(Moda<Mediana<Średnia)

# %% [markdown]
# ### Zakres

# %%
range_fare = max(fare_values) - min(fare_values)
range_fare
# Out:
# 512.3292

# %% [markdown]
# W tym przypadku zakresem jest maksymalny wynik ponieważ minimalna opłata wynosiła 0.

# %% [markdown]
# ### Roztęp miedzykwartylowy

# %%
iqr = q3 - q1
iqr
# Out:
# 23.0

# %% [markdown]
# Usuwamy 25% największych i najmniejszych wartości zbioru.

# %%
plt.boxplot(fare_values)
plt.show()

# %% [markdown]
# ### Wariancja i odchylenie standardowe

# %%
variance_fare = np.var(fare_values, ddof=1)
variance_fare
# Out:
# 2469.436845743116

# %%
standard_deviation_fare = np.std(fare_values, ddof=1)
standard_deviation_fare
# Out:
# 49.6934285971809

# %% [markdown]
# ### Standaryzajca

# %%
scaler_standardized = StandardScaler()
standardized_fare_values = scaler_standardized.fit_transform(fare_values.reshape(-1, 1))
plt.hist(standardized_fare_values, bins=20)
plt.axvline(x = standardized_fare_values.mean(), color='red', label = 'Średnia', linestyle = '--')
plt.show()
print(f'Średnia: {standardized_fare_values.mean()}')
print(f'Odchylenie standardowe: {np.std(standardized_fare_values, ddof=1)}')
# Out:
# Średnia: 3.987332972840069e-18
# Odchylenie standardowe: 1.0005616400330457

# %% [markdown]
# ### Min Max Scaler

# %%
scaler_MinMax = MinMaxScaler()
normalized_fare_values = scaler_MinMax.fit_transform(fare_values.reshape(-1, 1))
plt.hist(normalized_fare_values, bins=20)
plt.axvline(x = normalized_fare_values.mean(), color='red', label = 'Średnia', linestyle = '--')
plt.show()
print(f'Średnia: {normalized_fare_values.mean()}')
print(f'Odchylenie standardowe: {np.std(normalized_fare_values, ddof=1)}')
# Out:
# Średnia: 0.06285842768394742
# Odchylenie standardowe: 0.09699511290236998
